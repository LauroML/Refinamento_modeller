# %%
from modeller import *
from modeller.automodel import *

# Inicializa o ambiente do Modeller
log.verbose()
env = Environ()

env.io.atom_files_directory = ['.', '../atom_files']

# Definindo a classe MyLoopModel, baseada em AutoModel
class MyLoopModel(LoopModel):
    def select_loop_atoms(self):
        # Seleciona os resíduos a serem refinados
        return Selection(            
            self.residue_range('733:A', '738:A'), # Corrigido para 1129:A, 1134:A
            self.residue_range('1160:A', '1170:A'),
            self.residue_range('1313:A', '1317:A'),
            self.residue_range('1632:A', '1639:A'),         
        )

# Criação do modelo de loop com a estrutura existente
a = MyLoopModel(env,
                inimodel='novo.pdb',   # Modelo inicial da proteína
                sequence='Q99572',                 # Código da sequência alvo
                loop_assess_methods=assess.DOPE)   # Método de avaliação DOPE

# Definindo os parâmetros do modelo
a.starting_model = 1
a.ending_model = 1  # Apenas um modelo será gerado
a.loop.md_level = refine.very_slow  # Nível de refinamento (pode ser alterado conforme necessário)

# Executando a construção do modelo
a.make()
# Out:
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL10v6}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL10v6}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     71550340   69873.375    68.236
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     71550868   69873.891    68.236
# openf___224_> Open           ${MODINSTALL10v6}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     71599468   69921.359    68.283
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL10v6}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:     71612768   69934.344    68.295
# ...

# %%
from modeller import *
from modeller.automodel import *

# Inicializa o ambiente do Modeller
log.verbose()
env = Environ()

env.io.atom_files_directory = ['.', '../atom_files']

# Definindo a classe MyLoopModel, baseada em AutoModel
class MyLoopModel(LoopModel):
    def select_loop_atoms(self):
        # Seleciona os resíduos a serem refinados
        return Selection(
            self.residue_range('3:A', '5:A'),   # Corrigido para 3:A, 5:A
            self.residue_range('74:A', '77:A') ,  # Corrigido para 74:A, 77:A
            self.residue_range('150:A', '159:A'),# Corrigido para 150:A, 159:A
            self.residue_range('170:A', '174:A'), # Corrigido para 170:A, 174:A
            self.residue_range('165:A', '167:A'), # Corrigido para 165:A, 167:A
            self.residue_range('440:A', '443:A'), # Corrigido para 440:A, 443:A
            self.residue_range('464:A', '476:A'), # Corrigido para 464:A, 476:A
            self.residue_range('534:A', '539:A'), # Corrigido para 534:A, 539:A
            self.residue_range('592:A', '602:A'), # Corrigido para 592:A, 602:A
            self.residue_range('670:A', '673:A'), # Corrigido para 670:A, 673:A
            self.residue_range('765:A', '769:A'), # Corrigido para 765:A, 769:A
            self.residue_range('1057:A', '1077:A'), # Corrigido para 1057:A, 1077:A
            self.residue_range('1129:A', '1134:A'), # Corrigido para 1129:A, 1134:A
            self.residue_range('1187:A', '1197:A'), # Corrigido para 1187:A, 1197:A
            self.residue_range('1264:A', '1271:A'), # Corrigido para 1264:A, 1271:A
            self.residue_range('1360:A', '1364:A'), # Corrigido para 1360:A, 1364:A
            self.residue_range('1625:A', '1637:A'), # Corrigido para 1625:A, 1637:A
            self.residue_range('1656:A', '1661:A'), # Corrigido para 1656:A, 1661:A
            self.residue_range('1672:A', '1676:A'), # Corrigido para 1672:A, 1676:A
            self.residue_range('1724:A', '1729:A')   # Corrigido para 1724:A, 1729:A
        )

# Criação do modelo de loop com a estrutura existente
a = MyLoopModel(env,
                inimodel='Q99572.B99990036.pdb',   # Modelo inicial da proteína
                sequence='Q99572',                 # Código da sequência alvo
                loop_assess_methods=assess.DOPE)   # Método de avaliação DOPE

# Definindo os parâmetros do modelo
a.starting_model = 1
a.ending_model = 1  # Apenas um modelo será gerado
a.loop.starting_model = 1
a.loop.ending_model = 1
a.loop.md_level = refine.slow  # Nível de refinamento (pode ser alterado conforme necessário)

# Executando a construção do modelo
a.make()
